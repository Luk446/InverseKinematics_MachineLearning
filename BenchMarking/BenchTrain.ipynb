# %% [markdown]
# # PreReqs
#
# Import essential libraries, split into three chunks
# - machine learning packaages
# - tuning for auto-hyperparameter selection
# - linear algerba, data-manipulation and miscellanious QOL

# %%
# Package installation - python version must be 3.12 or below due to comptability with some modules
# "type : ignore" used to stop error reporting of non resolve (not relevant)

# ML from PyTorch
import torch # type: ignore
import torch.optim as optim # type: ignore
import torch.nn.functional as F # type: ignore
from torch import nn # type: ignore
from torch.utils.data import Dataset, DataLoader # type: ignore
from torch.utils.data import random_split  # type: ignore
from torchvision.transforms import ToTensor # type: ignore
from torch.utils.data import TensorDataset, DataLoader # type: ignore
import torchvision # type: ignore
import torchvision.transforms as transforms # type: ignore
from torchmetrics.regression import MeanAbsolutePercentageError  # type: ignore

# Tuning from Ray 
import ray # type: ignore
from ray import tune  # type: ignore
from ray import train  # type: ignore
from ray.tune import CLIReporter  # type: ignore
from ray.tune.schedulers import ASHAScheduler  # type: ignore
from ray.train import Checkpoint, get_checkpoint  # type: ignore
from ray.tune.schedulers import ASHAScheduler  # type: ignore
import ray.cloudpickle as pickle  # type: ignore


# Linear algebra, array manip and data analysis
import numpy as np # type: ignore
import pandas as pd # type: ignore
import matplotlib.pyplot as plt  # type: ignore
from mpl_toolkits.mplot3d import Axes3D # type: ignore
from sklearn.model_selection import train_test_split # type: ignore
from sklearn.preprocessing import StandardScaler # type: ignore

# misc
from functools import partial
import os
import tempfile
from pathlib import Path

# %%
# Block used if neccesary for trouble shooting to check whether CUDA is working

"""
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")

"""
# Out:
# '\ndevice = (\n    "cuda"\n    if torch.cuda.is_available()\n    else "mps"\n    if torch.backends.mps.is_available()\n    else "cpu"\n)\nprint(f"Using {device} device")\n\n'

# %% [markdown]
# # Data import, conversion and preparation
#
# - importing the data from the csv and previewing
# - extrapolate the data into targets (I) and inputs (C)
# - split the data chunks into training testing and validation
#     -    The data is split into training (80%), validation (20% of the remaining 80%), and test sets using train_test_split
# - The data is then normalised with StandardScaler and converted into pytorch tensors (now compatible with learning)

# %%
# Pandas data import 
data = pd.read_csv('robot_inverse_kinematics_dataset.csv')
data.head()
# Out:
#      q1     q2    q3     q4      q5     q6       x       y      z
# 0 -1.51 -0.763  1.85 -0.817  0.9120  2.320 -0.0947  0.1500  0.301
# 1 -2.84  0.520  1.58 -1.270 -1.3900  0.617  0.1420 -0.1000  0.225
# 2 -1.23  0.695  1.22 -1.130  0.0343  6.270 -0.0833  0.2230  0.206
# 3 -1.99  1.060  1.74 -1.760 -1.2400  4.760  0.1350 -0.0314  0.370
# 4  1.05  0.836  1.34 -1.890  0.4840  4.380 -0.0560 -0.2290  0.260

# %%
# extrap data and create arrays
I = data[['x','y','z']].values
C = data[['q1','q2','q3']].values

# %%
"""
- split the data into training and testing sets
- 80% of the data will be used for training, 20% for testing
- the random state is set to 30 to ensure the same result each time the function is called
- the data is split into 4 arrays: I_train, I_test, C_train, C_test
- I_train and C_train will be used to train the model
- I_test and C_test will be used to test the model
- the shape of the data is printed to confirm the split
"""

# splits the data into 80% training and 20% testing for both I and C
I_train,I_test,C_train,C_test=train_test_split(I,C,test_size=0.2,random_state=30)
# arrays (I,C) , split size (20%) , int in random state allows for same result each time func is called 

# splits the data again , out of the 80 (training) take another 20 for validation 
I_train,I_val,C_train,C_val=train_test_split(I_train,C_train,test_size=0.25,random_state=30)
# arrays (I and C train) , 25% , rand. int

# print the shape of the data to confirm the splits
print(f"I_train: {I_train.shape}, C_train: {C_train.shape}")
print(f"I_test: {I_test.shape}, C_test: {C_test.shape}")
print(f"I_val: {I_val.shape}, C_val: {C_val.shape}")
# Out:
# I_train: (9000, 3), C_train: (9000, 3)
# I_test: (3000, 3), C_test: (3000, 3)
# I_val: (3000, 3), C_val: (3000, 3)

# %%
"""
- Normalise the input features and target values
- Fit the scalers on the training data and transform all splits
- Convert to PyTorch tensors
"""

# Normalise the input features and target values
scaler_input = StandardScaler()
scaler_output = StandardScaler()


# Fit the scalers on the training data and transform all splits
I_train = scaler_input.fit_transform(I_train)
I_val = scaler_input.transform(I_val)
I_test = scaler_input.transform(I_test)

C_train = scaler_output.fit_transform(C_train)
C_val = scaler_output.transform(C_val)
C_test = scaler_output.transform(C_test)

# Convert to PyTorch tensors
I_train = torch.tensor(I_train, dtype=torch.float32)
I_val = torch.tensor(I_val, dtype=torch.float32)
I_test = torch.tensor(I_test, dtype=torch.float32)

C_train = torch.tensor(C_train, dtype=torch.float32)
C_val = torch.tensor(C_val, dtype=torch.float32)
C_test = torch.tensor(C_test, dtype=torch.float32)

# %% [markdown]
# # Model section
#
# - a multi-layer precepteron regressor class is defined
#     - 3 points on input and output layer - to match data (x,y,z) -> (p1,p2,p3)
#     - l1, l2 and l3 hidden layer configurations
#     - dropout layers between each to prevent over fitting

# %%
"""
- Define the MLPRegressor class
- The class inherits from nn.Module
- The class has a constructor that takes the following parameters:
    - l1: number of neurons in the first hidden layer
    - l2: number of neurons in the second hidden layer
    - l3: number of neurons in the third hidden layer
    - activation: activation function to use in the hidden layers
    - dropout_prob: dropout probability
"""

class MLPRegressor(nn.Module):

    # Define the model architecture
    def __init__(self, l1=120, l2=84, l3=10, activation='Tanh', dropout_prob=0.2): # set defaults here 
        # Call the parent class constructor
        super(MLPRegressor, self).__init__()

        # Dynamically choose the activation function based on config
        self.activation = getattr(nn, activation.capitalize(), nn.Tanh)() 

        # Define hidden layer params 
        self.hidden_layers = nn.Sequential(
            nn.Linear(3, l1), # input layer -> hidden
            self.activation, # acitviation function configured in search space
            nn.Dropout(p=dropout_prob), # drop out layer - probability config in search space
            nn.Linear(l1, l2), # hidden 1 -> 2
            self.activation,
            nn.Dropout(p=dropout_prob),
            nn.Linear(l2, l3), # hidden 2 -> 3
            self.activation,
            nn.Dropout(p=dropout_prob)
        )
        
        # Define output layer with 3 outputs
        self.output_layer = nn.Linear(l3, 3)  # hidden 3 -> output
        
    # Define the forward pass    
    def forward(self, x): # x is the input data
        x = self.hidden_layers(x) # pass through hidden layers
        return self.output_layer(x) # pass through output layer

# %% [markdown]
# # Training function
#
# - The train function accepts a configuration dictionary for hyperparameters (l1, l2) and trains the MLPRegressor model.
# - Loss is computed with nn.MSELoss, and the model is optimized using NAdam. The script also handles checkpointing with Ray Tune.
# - Validation Metrics: The script calculates validation loss and Mean Absolute Percentage Error (MAPE) for each epoch.

# %%
def train(config, data_dir=None, max_epochs=1000):

    # Initialize the checkpoint directory outside of any conditionals
    checkpoint_dir = "./checkpoints"  # This ensures it's defined before use
    os.makedirs(checkpoint_dir, exist_ok=True) # create the directory if it doesn't exist

    """
    Preliminary section
     - deining the mode
     - device allocation
     - selecting criterion and optimiser
     - creation of the data loaders for train and eval
     - checkpointing logic
    """
    
    # define model with variables configurable in the mlpr class def 
    model = MLPRegressor(
        l1=config["l1"],
        l2=config["l2"],
        l3=config["l3"],
        activation=config["activation"],
        dropout_prob=config["dropout_prob"]
    )
    
    # use the cuda device if available
    device = "cuda:0" if torch.cuda.is_available() else "cpu"
    # check for parralel computing ability 
    if torch.cuda.device_count() > 1:
        model = nn.DataParallel(model)
    # assign the model to the chosen device
    model.to(device)
    
    # set for regression using mean squared error loss
    criterion = nn.MSELoss()

    # Each optimiser has its own variables so they are defined here by checking which one is being used
    if config["optimiser"] == "NAdam":
        optimiser = optim.NAdam(model.parameters(), lr=config["learning_rate_init"], betas=(config["momentum"], 0.999))
    elif config["optimiser"] == "AdamW":
        optimiser = optim.AdamW(model.parameters(), lr=config["learning_rate_init"], betas=(config["momentum"], 0.999), weight_decay=1e-4)
    elif config["optimiser"] == "RAdam":
        optimiser = optim.RAdam(model.parameters(), lr=config["learning_rate_init"], betas=(config["momentum"], 0.999))
    elif config["optimiser"] == "SGD":
        optimiser = optim.SGD(model.parameters(), lr=config["learning_rate_init"], momentum=config["momentum"], weight_decay=1e-4)
    elif config["optimiser"] == "Adam":
        optimiser = optim.Adam(model.parameters(), lr=config["learning_rate_init"], betas=(config["momentum"], 0.999))


    # For batch sizing to be available we need to use data loading 

    # Training dataset
    train_loader = DataLoader(
        TensorDataset(I_train, C_train),
        batch_size=config["batch_size"],
        shuffle=True
    )
    # Validation dataset
    val_loader = DataLoader(
        TensorDataset(I_val, C_val),
        batch_size=config["batch_size"]
    )

    # fetch the checkpoint for resuming the trial
    checkpoint = get_checkpoint() # get the checkpoint from the trial
    if checkpoint: # if there is a checkpoint
        with checkpoint.as_directory() as checkpoint_dir: # open the directory
            data_path = Path(checkpoint_dir) / "data.pkl" # get the data path
            with open(data_path, "rb") as fp:           # open the file
                checkpoint_state = pickle.load(fp)      # load the checkpoint state
            start_epoch = checkpoint_state["epoch"]     # get the epoch from the checkpoint
            model.load_state_dict(checkpoint_state["model_state_dict"]) # load the model state
            optimiser.load_state_dict(checkpoint_state["optimizer_state_dict"]) # load the optimiser state
    else: # if there is no checkpoint
        start_epoch = 0 # start the epoch at 0
    
    """
    Training and evaluation loops 
    - loops over a max defined range in the function definition 
    - train first 
    - check results using eval
    """

    for epoch in range(start_epoch, max_epochs):  # loop over the dataset multiple times


        """
        Train section
        - put into training mode
        - init the variables used to track the training progress
        - run  forwards and backwards over the model
        """

        model.train()
        running_loss = 0.0
        # epoch_steps = 0

        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)

            # forward + backward + optimize
            optimiser.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimiser.step()
            running_loss += loss.item()
        

        """
        Eval section
        - put into eval mode
        - init tracking variables
        - execute model validation using val set
        """

        # eval mode
        model.eval()

        # Validation variable inits
        val_loss = 0.0
        mape_total = 0.0

        with torch.no_grad(): 
            for inputs, targets in val_loader:

                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)

                # Calculate loss
                val_loss += criterion(outputs, targets).item()

                # Calculate MAPE
                mapecalc = MeanAbsolutePercentageError().to(device)
                mape_total += mapecalc(outputs, targets).item()

        
        """
        Tracking section 
        - track the running average of the stats
        - keep a checkpoint of the trail
        - report stats into the ray tune progress reporter
        """

        # track the average of the eval statistics 

        avg_val_loss = val_loss / len(val_loader)
        avg_mape = mape_total / len(val_loader)

        # keep a checkpoint of the trails as they run 
        checkpoint_data = {
            "epoch": epoch,
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimiser.state_dict(),
        }
        # checkpoint saving
          # Create a temporary directory for each checkpoint
        with tempfile.TemporaryDirectory() as checkpoint_dir:
            data_path = os.path.join(checkpoint_dir, "data.pkl")
            with open(data_path, "wb") as fp:
                pickle.dump(checkpoint_data, fp)

            # Provide the checkpoint to Ray
            checkpoint = Checkpoint.from_directory(checkpoint_dir)

            # report the stats to the ray tune progress reporter
            ray.train.report(
                {"loss": avg_val_loss, "mape": avg_mape},
                checkpoint=checkpoint
            )


    
    print("Finished Training")

# %% [markdown]
# # Hyperparmater tuning with ray tune
#
# The main function is the core of the tuning
# - sets up Ray Tune to optimize hyperparameters
#     - activation
#     - alpha
#     - layer sizes
#     - learning rate
#     - iterations
#     - tol
#     - momentum
#     - val frac
# - An ASHA Scheduler (ASHAScheduler) is used to terminate underperforming trials early.
# - Resource Allocation: The script dynamically assigns CPU and GPU resources based on availability.

# %%
def main(num_samples=10, max_num_epochs=1000): 

    """
    - Allocate resources based on the available resources
    - Define the hyper-parameter search space
    - Define the early stopping scheduler
    - Define the checkpoint directory
    - Run the hyper-parameter search
    - Load the best checkpoint
    - Save the best trained model
    """

    # Allocate based on available resources
    resources = ray.cluster_resources()
    available_cpus = int(resources.get("CPU", 0))
    available_gpus = int(resources.get("GPU", 0))

    resources_per_trial = {
        "cpu": max(1, available_cpus // num_samples),
        "gpu": max(1, available_gpus) if available_gpus > 0 else 0
    }

    # hyper-parameter search area 
    config = {
        "activation": tune.choice(['tanh', 'RReLU', 'Hardtanh', 'identity','LeakyReLU']),
        "alpha": tune.loguniform(1e-5, 1e-2),
        "batch_size": tune.choice([8, 32, 128, 256]),
        "l1": tune.choice([2**i for i in range(12)]),
        "l2": tune.choice([2**i for i in range(12)]),
        "l3": tune.choice([2**i for i in range(11)]),
        "learning_rate_init": tune.loguniform(1e-6, 1e-1),
        "max_iter": tune.choice([4000,10000,15000,20000]),
        "tol": tune.loguniform(1e-4, 1e-3),
        "momentum": tune.uniform(0.5, 0.99),
        "validation_fraction": tune.uniform(0.1, 0.3),
        "dropout_prob": tune.uniform(0.1,0.3),
        "optimiser": tune.choice(['NAdam', 'AdamW', 'RAdam', 'SGD', 'Adam'])
    }
    
    # early stopping for trials with bad mape values
    scheduler = ASHAScheduler(
        metric="mape",
        mode="min",
        max_t=max_num_epochs,
        grace_period=10,
        reduction_factor=2,
    )

    # checkpoint bugfix for names being too long
    def short_dirname(trial):
        return "trial_" + str(trial.trial_id)

    # send values into the progress reporter in the output 
    result = tune.run(
        partial(train, max_epochs=max_num_epochs),
        resources_per_trial=resources_per_trial,
        config=config,
        num_samples=num_samples,
        scheduler=scheduler,
        trial_dirname_creator=short_dirname
    )

    # get best trial 
    best_trial = result.get_best_trial("mape", "min", "last")
    print(f"Best trial config: {best_trial.config}")
    print(f"Best trial final mape: {best_trial.last_result['mape']}")


    # Define the best trained model with the same hyper parameters decided in the config space 
    best_trained_model = MLPRegressor(
        l1=best_trial.config["l1"],
        l2=best_trial.config["l2"],
        l3=best_trial.config["l3"],
        activation=best_trial.config["activation"],
        dropout_prob=best_trial.config["dropout_prob"],
        )

    # Device selection 
    device = "cuda:0" if torch.cuda.is_available() else "cpu"
    if torch.cuda.device_count() > 1:
        best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)


    # Load the best checkpoint
    best_checkpoint = result.get_best_checkpoint(best_trial, metric="mape", mode="min")
    if best_checkpoint:
        with best_checkpoint.as_directory() as checkpoint_dir:
            checkpoint_path = Path(checkpoint_dir) / "data.pkl"
            with open(checkpoint_path, "rb") as fp:
                checkpoint_state = pickle.load(fp)
            best_trained_model.load_state_dict(checkpoint_state["model_state_dict"])
        print(f"Best checkpoint loaded from: {best_checkpoint}")
    else:
        print("No checkpoint found for the best trial.")

    # Save the best trained model
    torch.save(best_trained_model,"BenchTrain.pickle")

# %%
# ray init function
if not ray.is_initialized():
        ray.init()
# main function call
if __name__ == "__main__":
    # check for ray init
    if not ray.is_initialized():
        ray.init()

    try:
        main()
    # catch the error if the file is not found
    except FileNotFoundError as e:
        print(f"FileNotFoundError: {e}")
# Out:
# 2025-03-12 16:26:11,501	INFO worker.py:1816 -- Started a local Ray instance.
# 2025-03-12 16:26:26,566	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-03-12 17:27:52</td></tr>
# <tr><td>Running for: </td><td>01:01:26.23        </td></tr>
# <tr><td>Memory:      </td><td>26.9/127.8 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=10<br>Bracket: Iter 640.000: -4.181737512350082 | Iter 320.000: -3.829936100323995 | Iter 160.000: -3.5781690061887104 | Iter 80.000: -3.0017792784372967 | Iter 40.000: -2.450301808834076 | Iter 20.000: -3.209007792016293 | Iter 10.000: -3.5220995222528773<br>Logical resource usage: 6.0/64 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:RTX)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name       </th><th>status    </th><th>loc            </th><th>activation  </th><th style="text-align: right;">      alpha</th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout_prob</th><th style="text-align: right;">  l1</th><th style="text-align: right;">  l2</th><th style="text-align: right;">  l3</th><th style="text-align: right;">  learning_rate_init</th><th style="text-align: right;">  max_iter</th><th style="text-align: right;">  momentum</th><th>optimiser  </th><th style="text-align: right;">        tol</th><th style="text-align: right;">  validation_fraction</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    loss</th><th style="text-align: right;">   mape</th></tr>
# </thead>
# <tbody>
# <tr><td>train_bee0a_00000</td><td>TERMINATED</td><td>127.0.0.1:18384</td><td>RReLU       </td><td style="text-align: right;">0.000476787</td><td style="text-align: right;">         256</td><td style="text-align: right;">      0.230825</td><td style="text-align: right;">   2</td><td style="text-align: right;">1024</td><td style="text-align: right;">   1</td><td style="text-align: right;">         0.0202865  </td><td style="text-align: right;">      4000</td><td style="text-align: right;">  0.580869</td><td>SGD        </td><td style="text-align: right;">0.00011921 </td><td style="text-align: right;">             0.191677</td><td style="text-align: right;">  1000</td><td style="text-align: right;">       219.571  </td><td style="text-align: right;">0.859657</td><td style="text-align: right;">3.81555</td></tr>
# <tr><td>train_bee0a_00001</td><td>TERMINATED</td><td>127.0.0.1:29596</td><td>Hardtanh    </td><td style="text-align: right;">6.44543e-05</td><td style="text-align: right;">           8</td><td style="text-align: right;">      0.215015</td><td style="text-align: right;"> 128</td><td style="text-align: right;">  16</td><td style="text-align: right;">   1</td><td style="text-align: right;">         1.84527e-05</td><td style="text-align: right;">     15000</td><td style="text-align: right;">  0.679625</td><td>SGD        </td><td style="text-align: right;">0.000625081</td><td style="text-align: right;">             0.172068</td><td style="text-align: right;">  1000</td><td style="text-align: right;">      2985.07   </td><td style="text-align: right;">0.856742</td><td style="text-align: right;">4.14392</td></tr>
# <tr><td>train_bee0a_00002</td><td>TERMINATED</td><td>127.0.0.1:3836 </td><td>Hardtanh    </td><td style="text-align: right;">0.00946217 </td><td style="text-align: right;">         128</td><td style="text-align: right;">      0.158995</td><td style="text-align: right;">  32</td><td style="text-align: right;">   8</td><td style="text-align: right;"> 512</td><td style="text-align: right;">         5.81353e-05</td><td style="text-align: right;">     20000</td><td style="text-align: right;">  0.818895</td><td>AdamW      </td><td style="text-align: right;">0.000146058</td><td style="text-align: right;">             0.252481</td><td style="text-align: right;">    10</td><td style="text-align: right;">         4.32235</td><td style="text-align: right;">0.828817</td><td style="text-align: right;">3.67107</td></tr>
# <tr><td>train_bee0a_00003</td><td>TERMINATED</td><td>127.0.0.1:37408</td><td>identity    </td><td style="text-align: right;">0.00021863 </td><td style="text-align: right;">          32</td><td style="text-align: right;">      0.229722</td><td style="text-align: right;"> 256</td><td style="text-align: right;">   8</td><td style="text-align: right;">1024</td><td style="text-align: right;">         2.30286e-05</td><td style="text-align: right;">     20000</td><td style="text-align: right;">  0.644548</td><td>NAdam      </td><td style="text-align: right;">0.000196257</td><td style="text-align: right;">             0.263387</td><td style="text-align: right;">    10</td><td style="text-align: right;">         9.753  </td><td style="text-align: right;">0.834694</td><td style="text-align: right;">4.21109</td></tr>
# <tr><td>train_bee0a_00004</td><td>TERMINATED</td><td>127.0.0.1:44188</td><td>LeakyReLU   </td><td style="text-align: right;">5.79988e-05</td><td style="text-align: right;">           8</td><td style="text-align: right;">      0.227304</td><td style="text-align: right;">2048</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">         0.0198996  </td><td style="text-align: right;">      4000</td><td style="text-align: right;">  0.623151</td><td>RAdam      </td><td style="text-align: right;">0.000329838</td><td style="text-align: right;">             0.200933</td><td style="text-align: right;">    10</td><td style="text-align: right;">        35.9598 </td><td style="text-align: right;">1.69265 </td><td style="text-align: right;">9.78976</td></tr>
# <tr><td>train_bee0a_00005</td><td>TERMINATED</td><td>127.0.0.1:30156</td><td>RReLU       </td><td style="text-align: right;">0.000706371</td><td style="text-align: right;">         128</td><td style="text-align: right;">      0.268343</td><td style="text-align: right;">   4</td><td style="text-align: right;">   2</td><td style="text-align: right;">   8</td><td style="text-align: right;">         1.12611e-05</td><td style="text-align: right;">     10000</td><td style="text-align: right;">  0.958611</td><td>AdamW      </td><td style="text-align: right;">0.00024023 </td><td style="text-align: right;">             0.151136</td><td style="text-align: right;">  1000</td><td style="text-align: right;">       307.924  </td><td style="text-align: right;">0.851704</td><td style="text-align: right;">4.32714</td></tr>
# <tr><td>train_bee0a_00006</td><td>TERMINATED</td><td>127.0.0.1:5316 </td><td>Hardtanh    </td><td style="text-align: right;">0.0032281  </td><td style="text-align: right;">          32</td><td style="text-align: right;">      0.272121</td><td style="text-align: right;">1024</td><td style="text-align: right;"> 512</td><td style="text-align: right;">  64</td><td style="text-align: right;">         0.0252332  </td><td style="text-align: right;">     10000</td><td style="text-align: right;">  0.849442</td><td>Adam       </td><td style="text-align: right;">0.000156901</td><td style="text-align: right;">             0.114805</td><td style="text-align: right;">    10</td><td style="text-align: right;">        11.1234 </td><td style="text-align: right;">0.943626</td><td style="text-align: right;">6.05975</td></tr>
# <tr><td>train_bee0a_00007</td><td>TERMINATED</td><td>127.0.0.1:16796</td><td>tanh        </td><td style="text-align: right;">0.000322231</td><td style="text-align: right;">          32</td><td style="text-align: right;">      0.11229 </td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  64</td><td style="text-align: right;">         1.20142e-05</td><td style="text-align: right;">     1
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name       </th><th style="text-align: right;">    loss</th><th style="text-align: right;">   mape</th><th>should_checkpoint  </th></tr>
# </thead>
# <tbody>
# <tr><td>train_bee0a_00000</td><td style="text-align: right;">0.859657</td><td style="text-align: right;">3.81555</td><td>True               </td></tr>
# <tr><td>train_bee0a_00001</td><td style="text-align: right;">0.856742</td><td style="text-align: right;">4.14392</td><td>True               </td></tr>
# <tr><td>train_bee0a_00002</td><td style="text-align: right;">0.828817</td><td style="text-align: right;">3.67107</td><td>True               </td></tr>
# <tr><td>train_bee0a_00003</td><td style="text-align: right;">0.834694</td><td style="text-align: right;">4.21109</td><td>True               </td></tr>
# <tr><td>train_bee0a_00004</td><td style="text-align: right;">1.69265 </td><td style="text-align: right;">9.78976</td><td>True               </td></tr>
# <tr><td>train_bee0a_00005</td><td style="text-align: right;">0.851704</td><td style="text-align: right;">4.32714</td><td>True               </td></tr>
# <tr><td>train_bee0a_00006</td><td style="text-align: right;">0.943626</td><td style="text-align: right;">6.05975</td><td>True               </td></tr>
# <tr><td>train_bee0a_00007</td><td style="text-align: right;">0.825949</td><td style="text-align: right;">4.66842</td><td>True               </td></tr>
# <tr><td>train_bee0a_00008</td><td style="text-align: right;">0.864413</td><td style="text-align: right;">3.20901</td><td>True               </td></tr>
# <tr><td>train_bee0a_00009</td><td style="text-align: right;">0.899102</td><td style="text-align: right;">4.04975</td><td>True               </td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000000)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000001)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000002)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000003)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000004)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000005)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000006)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000007)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000008)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000009)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000010)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000011)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000012)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000013)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000014)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000015)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000016)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000017)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000018)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000019)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000020)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000021)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000022)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000023)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000024)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000025)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000026)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000027)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000028)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000029)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000030)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000031)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000032)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000033)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000034)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000035)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000036)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000037)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000038)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000039)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000040)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000041)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000042)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000043)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000044)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000045)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000046)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000047)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000048)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000049)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000050)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000051)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000052)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000053)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000054)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000055)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000056)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000057)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000058)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000059)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000060)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000061)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000062)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000063)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000064)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000065)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000066)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000067)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000068)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000069)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000070)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000071)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000072)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000073)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000074)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000075)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000076)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000077)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000078)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000079)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000080)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000081)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000082)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000083)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000084)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000085)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000086)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000087)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000088)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000089)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000090)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000091)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000092)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000093)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000094)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000095)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000096)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000097)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000098)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000099)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000100)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000101)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000102)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000103)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000104)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000105)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000106)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000107)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000108)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000109)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000110)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000111)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000112)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000113)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000114)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000115)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000116)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000117)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000118)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000119)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000120)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000121)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000122)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000123)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000124)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000125)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000126)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000127)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000128)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000129)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000130)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000131)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000132)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000133)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000134)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000135)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000136)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000137)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000138)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000139)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000140)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000141)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000142)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000143)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000144)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000145)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000146)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000147)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000148)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000149)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000150)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000151)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000152)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000153)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000154)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000155)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000156)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000157)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000158)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000159)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000160)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000161)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000162)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000163)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000164)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000165)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000166)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000167)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000168)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000169)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000170)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000171)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000172)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000173)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000174)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000175)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000176)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000177)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000178)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000179)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000180)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000181)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000182)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000183)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000184)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000185)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000186)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000187)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000188)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000189)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000190)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000191)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000192)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000193)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000194)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000195)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000196)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000197)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000198)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000199)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000200)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000201)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000202)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000203)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000204)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000205)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000206)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000207)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000208)
# (func pid=18384) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00000/checkpoint_000209)
# ...
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000976)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000977)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000978)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000979)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000980)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000981)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000982)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000983)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000984)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000985)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000986)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000987)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000988)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000989)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000990)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000991)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000992)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000993)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000994)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000995)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000996)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000997)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000998)
# (func pid=30156) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00005/checkpoint_000999)
# (func pid=5316) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00006/checkpoint_000000)
# (func pid=5316) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00006/checkpoint_000001)
# (func pid=5316) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00006/checkpoint_000002)
# (func pid=5316) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00006/checkpoint_000003)
# (func pid=5316) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00006/checkpoint_000004)
# (func pid=5316) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00006/checkpoint_000005)
# (func pid=5316) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00006/checkpoint_000006)
# (func pid=5316) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00006/checkpoint_000007)
# (func pid=5316) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00006/checkpoint_000008)
# (func pid=5316) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00006/checkpoint_000009)
# (func pid=16796) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00007/checkpoint_000000)
# (func pid=16796) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00007/checkpoint_000001)
# (func pid=16796) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00007/checkpoint_000002)
# (func pid=16796) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00007/checkpoint_000003)
# (func pid=16796) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00007/checkpoint_000004)
# (func pid=16796) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00007/checkpoint_000005)
# (func pid=16796) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00007/checkpoint_000006)
# (func pid=16796) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00007/checkpoint_000007)
# (func pid=16796) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00007/checkpoint_000008)
# (func pid=16796) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00007/checkpoint_000009)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000000)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000001)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000002)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000003)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000004)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000005)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000006)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000007)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000008)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000009)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000010)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000011)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000012)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000013)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000014)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000015)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000016)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000017)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000018)
# (func pid=28728) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000019)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000000)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000001)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000002)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000003)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000004)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000005)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000006)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000007)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000008)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000009)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000010)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000011)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000012)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000013)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000014)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000015)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000016)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000017)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000018)
# (func pid=29004) Checkpoint successfully created at: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00009/checkpoint_000019)
# 2025-03-12 17:27:52,884	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to 'C:/Users/2450027/ray_results/train_2025-03-12_16-26-26' in 0.0545s.
# 2025-03-12 17:27:52,912	INFO tune.py:1041 -- Total run time: 3686.35 seconds (3686.17 seconds for the tuning loop).
# Best trial config: {'activation': 'identity', 'alpha': 0.001632478152832471, 'batch_size': 32, 'l1': 16, 'l2': 64, 'l3': 1, 'learning_rate_init': 0.0013164538084653437, 'max_iter': 10000, 'tol': 0.0005341589437214072, 'momentum': 0.7925901612309569, 'validation_fraction': 0.16161121463818579, 'dropout_prob': 0.24407722437624688, 'optimiser': 'SGD'}
# Best trial final mape: 3.209007792016293
# Best checkpoint loaded from: Checkpoint(filesystem=local, path=C:/Users/2450027/ray_results/train_2025-03-12_16-26-26/trial_bee0a_00008/checkpoint_000001)
